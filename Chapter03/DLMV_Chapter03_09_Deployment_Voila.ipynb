# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/PacktPublishing/Deep-Learning-Model-Visualization/blob/main/Chapter03/DLMV_Chapter03_09_Deployment_Voila.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Chapter 03 - 09 - Deploying Python Widgets with Voila

# %% [markdown]
# ## Download a notebook

# %%
# !wget "https://raw.githubusercontent.com/PacktPublishing/Deep-Learning-Model-Visualization/main/Chapter03/DLMV_Chapter03_02_GradientDescent.ipynb"
# Out:
# --2024-05-13 15:31:25--  https://raw.githubusercontent.com/PacktPublishing/Deep-Learning-Model-Visualization/main/Chapter03/DLMV_Chapter03_02_GradientDescent.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36409 (36K) [text/plain]
# Saving to: ‘DLMV_Chapter03_02_GradientDescent.ipynb’
#
# DLMV_Chapter03_02_G 100%[===================>]  35.56K  --.-KB/s    in 0.003s
#
# 2024-05-13 15:31:25 (10.8 MB/s) - ‘DLMV_Chapter03_02_GradientDescent.ipynb’ saved [36409/36409]

# %% [markdown]
# ## Upgrade ipywidgets

# %%
# Upgrade ipywidgets
# !pip install ipywidgets==8.1.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.6
#     Uninstalling widgetsnbextension-3.6.6:
#       Successfully uninstalled widgetsnbextension-3.6.6
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
import ipywidgets as widgets
widgets.__version__
# Out:
# '8.1.1'

# %% [markdown]
# ## Install Voila

# %%
# !pip install voila
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.3/383.3 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.10.0
#     Uninstalling nbclient-0.10.0:
#       Successfully uninstalled nbclient-0.10.0
#   Attempting uninstall: jupyter-server
# ...

# %%
import voila
voila.__version__
# Out:
# '0.5.6'

# %% [markdown]
# ## Install ngrok

# %%
# !pip install pyngrok

# %% [markdown]
# ## Authenticate and expose URL

# %%
from pyngrok import ngrok, conf
# url: https://dashboard.ngrok.com/get-started/your-authtoken
token = "2bjd7c9bCukHvnjH63ymEdsz35s_2R4FdXzSedygTJyDnueKS"
conf.get_default().auth_token = token

# Open a ngrok tunnel to the HTTP server
PORT = 8866
public_url = ngrok.connect(PORT).public_url
msg = " * ngrok tunnel \"{}\" -> \"http://127.0.0.1:{}/\""
print(msg.format(public_url, PORT))
print("On Colab, click on the first link (not the second one)")
# Out:
#  * ngrok tunnel "https://b9dd-34-71-136-198.ngrok-free.app" -> "http://127.0.0.1:8866/"

# %% [markdown]
# ## Start the application

# %%
# !voila --debug --no-browser --port=$PORT DLMV_Chapter03_02_GradientDescent.ipynb
# Out:
# [Voila] Looking for voila in /etc/jupyter
# [Voila] Looking for voila in /usr/local/etc/jupyter
# [Voila] Looking for voila in /usr/etc/jupyter
# [Voila] Looking for voila in /root/.local/etc/jupyter
# [Voila] Looking for voila in /root/.jupyter
# [Voila] Looking for voila in /content
# [Voila] using template: lab
# [Voila] template paths:
# 	/usr/local/share/jupyter/voila/templates/lab
# 	/usr/local/share/jupyter/nbconvert/templates/lab
# 	/usr/local/share/jupyter/voila/templates/base
# 	/usr/local/share/jupyter/nbconvert/templates/base
# 	/root/.local/share/jupyter
# 	/root/.local/share/jupyter/voila/templates
# 	/root/.local/share/jupyter/nbconvert/templates
# 	/usr/local/share/jupyter
# 	/usr/local/share/jupyter/voila/templates
# 	/usr/local/share/jupyter/nbconvert/templates
# 	/usr/share/jupyter
# 	/usr/share/jupyter/voila/templates
# 	/usr/share/jupyter/nbconvert/templates
# [Voila] static paths:
# 	/root/.local/share/jupyter/voila/templates/lab/static
# ...
